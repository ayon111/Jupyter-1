# %%
#print 1-10
#normal approach
#while loop

#[on_true]if[condition] else [on_false]
#finding the maximum of two numbers
x=10
y=15
max=0
max=x if(x>y)else  y
print(1)
print (2)
print(3)
print(4)
print(5)
print(5)
print(6)
print(7)
print(8)
print(9)
print(10)
i=1
while i<=10:
    print(i)
    i=i+1
i=1
while (i<=10):
    if(i%2==0):
        print(i)
    i+=1
sum=0
i=1
while i<=10:
    sum+=i
    i+=1
print('The sum is %s'%sum)

i=1
#break when i is 5
while i<=10:
    if(i==5):
        break
    print(i)
    i+=1
i=1    
while True:
    if(i==5):
        break
    print(i)
    i+=1
#break when the user inputs a negative muber


while True:
    num=int(input('Please enter a postive number  number:'))
    if(num>0):
        print(num**2)
    else:
        print('Sorry!you had entered a negative number')
        break
        
#warning-infinite loop -interrupt your kernel

i=1
while i<=10:
    print(i)
#to rescue- add i+=1

#print odd number only in the range 1-20

i = 0
while i < 20:
    i += 1
    if(i % 2 == 0):
        continue
    print(i)

n = 1
while n < 5:
    n = n + 1
    if n == 2:
        continue
    print(n)
print("Loop is finished")

for x in range(5):
  print(x)
for x in range(1,11):
  print(x)

for x in range(2, 6):
  print(x)
#increment 
for x in range(2, 30, 3):
  print(x)
for x in range(30, 0, -3):
  print(x)
for x in range(10, 0, -1):
  print(x)

sum=0
for x in range(1,10):
    if(x%2==0):
        sum+=x
print(f'Sum of even numbers is : {sum}')

#show all numbers divisble by 3 between 1-100
for x in range(1,101):
        if(x%3==0):
            print(x)
#break with for loop

i=5

i = 5

for i in (5, 10):
    if(i == 9):
        break
    else:
        print(i)


for x in range(1,10):
    pass
    print(x)

print(1,2, sep='#')

for i in range(1,21):
    
    print(i, end='\\')
    
print("Studytonight","has","been","created","for", sep = " _ ", end=" _STUDENTS")

len=0
st='Bangladesh'
for c in st:
    print(c)
    len+=1
print(f'String length is {len}')

for i in [1,2,3,4,5]:
    print(i)
    
lst=['apple','orange','cherry']

for item in lst:
    if(item=='orange'):
        print('Found Orange')
        break
lst=['apple','orange','cherry']

for item in lst:
    
    if(item=='orange'):
        continue
    print(item)
lst=['apple','orange','cherry']

counter=0
for i in lst:
    counter+=1
print(counter)
